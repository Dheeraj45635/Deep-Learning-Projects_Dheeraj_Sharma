# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.27.2-py3-none-any.whl (70 kB)
#      ---------------------------------------- 70.1/70.1 kB 3.7 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-win_amd64.whl (323 kB)
#      -------------------------------------- 323.6/323.6 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from openai) (4.64.1)
# Requirement already satisfied: requests>=2.20 in d:\anaconda\lib\site-packages (from openai) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.20->openai) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.20->openai) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests>=2.20->openai) (2.0.4)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-win_amd64.whl (34 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-win_amd64.whl (28 kB)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\lib\site-packages (from aiohttp->openai) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.8/56.8 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->openai) (0.4.5)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.2 yarl-1.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai
import urllib.request
from PIL import Image
import cv2
import matplotlib.pyplot as plt

# %%
openai.api_key = "Your own api"

# %%
img_response = openai.Image.create(
    prompt = 'an astronaut lounging in a tropical resort in space',
    n=2,
    size="512x512")    # 256x256, 512x512, 1024x1024

# %%
img_response
# Out:
# <OpenAIObject at 0x1520976d720> JSON: {
#   "created": 1678875236,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-Ye3zwDF07Hov54dWPiD6GOZu/user-V7HTIsQ8Gk62eXLInwmTBcwW/img-rprpigylDbM9vvqhKHzBwejU.png?st=2023-03-15T09%3A13%3A56Z&se=2023-03-15T11%3A13%3A56Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-03-14T21%3A10%3A47Z&ske=2023-03-15T21%3A10%3A47Z&sks=b&skv=2021-08-06&sig=YbMLCjAf930liwOWpZLsKyYxV5X1sbPi1x3GvJ2tMNs%3D"
#     },
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-Ye3zwDF07Hov54dWPiD6GOZu/user-V7HTIsQ8Gk62eXLInwmTBcwW/img-a4c2Dxp4GhnRAz97HbJNYVa4.png?st=2023-03-15T09%3A13%3A56Z&se=2023-03-15T11%3A13%3A56Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-03-14T21%3A10%3A47Z&ske=2023-03-15T21%3A10%3A47Z&sks=b&skv=2021-08-06&sig=xezLPJntQYsom3je4f4/3cMcpKkvePZrKByz21QABcU%3D"
#     }
#   ]
# }

# %%
img_response['data'][0]['url']
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-Ye3zwDF07Hov54dWPiD6GOZu/user-V7HTIsQ8Gk62eXLInwmTBcwW/img-rprpigylDbM9vvqhKHzBwejU.png?st=2023-03-15T09%3A13%3A56Z&se=2023-03-15T11%3A13%3A56Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-03-14T21%3A10%3A47Z&ske=2023-03-15T21%3A10%3A47Z&sks=b&skv=2021-08-06&sig=YbMLCjAf930liwOWpZLsKyYxV5X1sbPi1x3GvJ2tMNs%3D'

# %%
img_url = img_response['data'][0]['url']
img_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-Ye3zwDF07Hov54dWPiD6GOZu/user-V7HTIsQ8Gk62eXLInwmTBcwW/img-rprpigylDbM9vvqhKHzBwejU.png?st=2023-03-15T09%3A13%3A56Z&se=2023-03-15T11%3A13%3A56Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-03-14T21%3A10%3A47Z&ske=2023-03-15T21%3A10%3A47Z&sks=b&skv=2021-08-06&sig=YbMLCjAf930liwOWpZLsKyYxV5X1sbPi1x3GvJ2tMNs%3D'

# %%
urllib.request.urlretrieve(img_url, 'image.png')
# Out:
# ('image.png', <http.client.HTTPMessage at 0x1520978a1f0>)

# %%
img = cv2.imread("image.png")
plt.imshow(img)
